# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd

# %%
bandung = pd.read_csv("https://raw.githubusercontent.com/elsamaulida5/machine-learning/main/cleaned%20data/bandung_cleaned.csv")
bandung
# Out:
#                                                   Name  \
# 0    Laundryklin Sudirman ( Laundry Antar Jemput Ba...
# 1                                     The Laundry Room
# 2                       Nadhif Laundry ciroyom bandung
# 3                                Laundry Club Rajawali
# 4                                 EZpress Home Laundry
# ..                                                 ...
# 248                                Anyun fresh laundry
# 249  Dr Laundry Ujung Berung (Laundry Kiloan dan La...
# 250                                   yayamama laundry
# 251                                       La ' Laundry
# 252                      GWASH LAUNDRY EXPRESS CIJAMBE
#
#                                            Fulladdress       Municipality  \
# 0    Jl. Jend. Sudirman No.486, Ciroyom, Kec. Andir...            Ciroyom
# 1    Jl. Ciroyom No.95/77, Dungus Cariang, Kec. And...     Dungus Cariang
# 2    Gg. Sastra No.272/78, Dungus Cariang, Kec. And...     Dungus Cariang
# ...

# %%
# Separates the two objects in the 'Phones' column
bandung[['telephone','phone']] = bandung['Phones'].str.split(', ', expand=True)
bandung.drop(columns=['Phones'], inplace=True)

# %%
# Drop the telephone field
bandung.drop(columns=['telephone'], inplace=True)
bandung['phone']
# Out:
# 0      +62 851-7335-8871
# 1        +62 22 20562320
# 2         +62 22 6036296
# 3      +62 851-7324-7944
# 4      +62 823-2020-9878
#              ...
# 248    +62 878-2312-5559
# 249                  NaN
# 250    +62 857-2100-3866
# 251    +62 818-0946-7561
# 252     +62 811-2439-194
# Name: phone, Length: 253, dtype: object

# %%
bandung.columns
# Out:
# Index(['Name', 'Fulladdress', 'Municipality', 'Categories', 'Time Zone',
#        'Claimed', 'Review Count', 'Average Rating', 'Review URL',
#        'Google Maps URL', 'Latitude', 'Longitude', 'Website', 'Domain',
#        'Opening Hours', 'Featured Image', 'phone'],
#       dtype='object')

# %%
df_bandung = bandung[['Name', 'Fulladdress', 'Categories', 'phone', 'Review Count', 'Average Rating',
                      'Review URL', 'Google Maps URL', 'Latitude', 'Longitude', 'Website',
                     'Opening Hours', 'Featured Image']]
df_bandung
# Out:
#                                                   Name  \
# 0    Laundryklin Sudirman ( Laundry Antar Jemput Ba...
# 1                                     The Laundry Room
# 2                       Nadhif Laundry ciroyom bandung
# 3                                Laundry Club Rajawali
# 4                                 EZpress Home Laundry
# ..                                                 ...
# 248                                Anyun fresh laundry
# 249  Dr Laundry Ujung Berung (Laundry Kiloan dan La...
# 250                                   yayamama laundry
# 251                                       La ' Laundry
# 252                      GWASH LAUNDRY EXPRESS CIJAMBE
#
#                                            Fulladdress            Categories  \
# 0    Jl. Jend. Sudirman No.486, Ciroyom, Kec. Andir...        Layanan Binatu
# 1    Jl. Ciroyom No.95/77, Dungus Cariang, Kec. And...        Layanan Binatu
# ...

# %%
df_bandung.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             253 non-null    object
#  1   Fulladdress      253 non-null    object
#  2   Categories       253 non-null    object
#  3   phone            215 non-null    object
#  4   Review Count     250 non-null    float64
#  5   Average Rating   250 non-null    float64
#  6   Review URL       250 non-null    object
#  7   Google Maps URL  253 non-null    object
#  8   Latitude         253 non-null    float64
#  9   Longitude        253 non-null    float64
#  10  Website          84 non-null     object
#  11  Opening Hours    220 non-null    object
#  12  Featured Image   251 non-null    object
# dtypes: float64(4), object(9)
# memory usage: 25.8+ KB

# %%
rows_to_change = ['Review Count', 'Average Rating']
df_bandung[rows_to_change] = df_bandung[rows_to_change].fillna(value=0)
df_bandung
# Out:
# <ipython-input-8-9ddc089ff5cc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bandung[rows_to_change] = df_bandung[rows_to_change].fillna(value=0)
#                                                   Name  \
# 0    Laundryklin Sudirman ( Laundry Antar Jemput Ba...
# 1                                     The Laundry Room
# 2                       Nadhif Laundry ciroyom bandung
# 3                                Laundry Club Rajawali
# 4                                 EZpress Home Laundry
# ..                                                 ...
# 248                                Anyun fresh laundry
# 249  Dr Laundry Ujung Berung (Laundry Kiloan dan La...
# 250                                   yayamama laundry
# ...

# %%
# Fill in the blanks with 'None' because the data in those columns might be needed
# so the blanks are replaced with 'None' to avoid missing values.

df_bandung = df_bandung.fillna('None')
df_bandung
# Out:
#                                                   Name  \
# 0    Laundryklin Sudirman ( Laundry Antar Jemput Ba...
# 1                                     The Laundry Room
# 2                       Nadhif Laundry ciroyom bandung
# 3                                Laundry Club Rajawali
# 4                                 EZpress Home Laundry
# ..                                                 ...
# 248                                Anyun fresh laundry
# 249  Dr Laundry Ujung Berung (Laundry Kiloan dan La...
# 250                                   yayamama laundry
# 251                                       La ' Laundry
# 252                      GWASH LAUNDRY EXPRESS CIJAMBE
#
#                                            Fulladdress            Categories  \
# 0    Jl. Jend. Sudirman No.486, Ciroyom, Kec. Andir...        Layanan Binatu
# 1    Jl. Ciroyom No.95/77, Dungus Cariang, Kec. And...        Layanan Binatu
# ...

# %%
df_bandung['Review Count'] = df_bandung['Review Count'].astype(int)

# %%
df_bandung.isna().sum()
# Out:
# Name               0
# Fulladdress        0
# Categories         0
# phone              0
# Review Count       0
# Average Rating     0
# Review URL         0
# Google Maps URL    0
# Latitude           0
# Longitude          0
# Website            0
# Opening Hours      0
# Featured Image     0
# dtype: int64

# %%
semarang = pd.read_csv("https://raw.githubusercontent.com/elsamaulida5/machine-learning/main/cleaned%20data/semarang_cleaned.csv")
semarang
# Out:
#                                               Name  \
# 0                 Londi Laundry Digital 5 Semarang
# 1       Premium Plus Laundry Karangrejo Banyumanik
# 2                              Hai Laundry Premium
# 3    Angel laundry, Banyumanik & cuci motor damar,
# 4                   Tatarapi Laundry and Wet Clean
# ..                                             ...
# 112                                B Clean Laundry
# 113                                   Bara Laundry
# 114                                   Mido Laundry
# 115                                  LULUK LAUNDRY
# 116                                 In-Dry Laundry
#
#                                            Fulladdress  \
# 0    Jl. Durian Raya, Srondol Wetan, Kec. Banyumani...
# 1    Jl. Kr. Rejo Raya No.10, Banyumanik, Kec. Bany...
# 2    Blk. G Jl. Jati Raya No.5, Srondol Wetan, Kec....
# 3    Jl. Kanfer Raya No.1 Blok V, Pedalangan, Kec. ...
# 4    Jl. Durian Raya No.16, Srondol Wetan, Kec. Ban...
# ...

# %%
# Separates the two objects in the 'Phones' column
semarang[['telephone','phone']] = semarang['Phones'].str.split(', ', expand=True)
semarang.drop(columns=['Phones'], inplace=True)

# %%
# Drop the telephone field
semarang.drop(columns=['telephone'], inplace=True)
semarang['phone']
# Out:
# 0       +62 822-2303-5863
# 1       +62 813-8962-1980
# 2        +62 899-5634-881
# 3       +62 857-4835-2513
# 4        +62 811-2898-818
#               ...
# 112      +62 815-6559-911
# 113     +62 877-6690-9075
# 114    +62 882-0036-03612
# 115     +62 815-7526-1251
# 116     +62 813-3635-3736
# Name: phone, Length: 117, dtype: object

# %%
df_semarang = semarang[['Name', 'Fulladdress', 'Categories', 'phone', 'Review Count', 'Average Rating',
                      'Review URL', 'Google Maps URL', 'Latitude', 'Longitude', 'Website',
                     'Opening Hours', 'Featured Image']]
df_semarang
# Out:
#                                               Name  \
# 0                 Londi Laundry Digital 5 Semarang
# 1       Premium Plus Laundry Karangrejo Banyumanik
# 2                              Hai Laundry Premium
# 3    Angel laundry, Banyumanik & cuci motor damar,
# 4                   Tatarapi Laundry and Wet Clean
# ..                                             ...
# 112                                B Clean Laundry
# 113                                   Bara Laundry
# 114                                   Mido Laundry
# 115                                  LULUK LAUNDRY
# 116                                 In-Dry Laundry
#
#                                            Fulladdress  \
# 0    Jl. Durian Raya, Srondol Wetan, Kec. Banyumani...
# 1    Jl. Kr. Rejo Raya No.10, Banyumanik, Kec. Bany...
# 2    Blk. G Jl. Jati Raya No.5, Srondol Wetan, Kec....
# 3    Jl. Kanfer Raya No.1 Blok V, Pedalangan, Kec. ...
# 4    Jl. Durian Raya No.16, Srondol Wetan, Kec. Ban...
# ...

# %%
df_semarang.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             117 non-null    object
#  1   Fulladdress      117 non-null    object
#  2   Categories       117 non-null    object
#  3   phone            112 non-null    object
#  4   Review Count     117 non-null    int64
#  5   Average Rating   117 non-null    float64
#  6   Review URL       117 non-null    object
#  7   Google Maps URL  117 non-null    object
#  8   Latitude         117 non-null    float64
#  9   Longitude        117 non-null    float64
#  10  Website          28 non-null     object
#  11  Opening Hours    115 non-null    object
#  12  Featured Image   116 non-null    object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 12.0+ KB

# %%
# Fill in the blanks with 'None' because the data in those columns might be needed
# so the blanks are replaced with 'None' to avoid missing values.

df_semarang = df_semarang.fillna('None')
df_semarang
# Out:
#                                               Name  \
# 0                 Londi Laundry Digital 5 Semarang
# 1       Premium Plus Laundry Karangrejo Banyumanik
# 2                              Hai Laundry Premium
# 3    Angel laundry, Banyumanik & cuci motor damar,
# 4                   Tatarapi Laundry and Wet Clean
# ..                                             ...
# 112                                B Clean Laundry
# 113                                   Bara Laundry
# 114                                   Mido Laundry
# 115                                  LULUK LAUNDRY
# 116                                 In-Dry Laundry
#
#                                            Fulladdress  \
# 0    Jl. Durian Raya, Srondol Wetan, Kec. Banyumani...
# 1    Jl. Kr. Rejo Raya No.10, Banyumanik, Kec. Bany...
# 2    Blk. G Jl. Jati Raya No.5, Srondol Wetan, Kec....
# 3    Jl. Kanfer Raya No.1 Blok V, Pedalangan, Kec. ...
# 4    Jl. Durian Raya No.16, Srondol Wetan, Kec. Ban...
# ...

# %%
df_semarang.isna().sum()
# Out:
# Name               0
# Fulladdress        0
# Categories         0
# phone              0
# Review Count       0
# Average Rating     0
# Review URL         0
# Google Maps URL    0
# Latitude           0
# Longitude          0
# Website            0
# Opening Hours      0
# Featured Image     0
# dtype: int64

# %%
surabaya = pd.read_csv("https://raw.githubusercontent.com/elsamaulida5/machine-learning/main/cleaned%20data/Surabaya.csv")
surabaya
# Out:
#                         Name  \
# 0            Rabbani Laundry
# 1            ZAM ZAM Laundry
# 2               Twin laundry
# 3            EXPRESS Laundry
# 4           Laundry Asbar 22
# ..                       ...
# 290    Oxy Laundry Margorejo
# 291  @HOME Laundry Indonesia
# 292    Barokah Clean Laundry
# 293             Zuma Laundry
# 294           CICUCI Laundry
#
#                                            Fulladdress  \
# 0    Jl. Asem Raya No.5, Asem Rowo, Kec. Asem Rowo,...
# 1    Asemrowo IV No.16, Asem Rowo, Kec. Asem Rowo, ...
# 2    Jl. Asem Rowo Baru No.32, RT.001/RW.03, Asem R...
# 3    Jl. Asem Mulya V No.20, Asem Rowo, Kec. Asem R...
# 4    Jl. Asem Rowo Baru No.22, Asem Rowo, Kec. Asem...
# ..                                                 ...
# 290  Jl. Margorejo Indah No.28f, Margorejo, Kec. Wo...
# 291  No Jl. Siwalankerto Sel., Siwalankerto, Kec. W...
# 292  Jl. Wonocolo Pabrik Kulit No.89, Jemur Wonosar...
# ...

# %%
df_surabaya = surabaya[['Name', 'Fulladdress', 'Categories', 'phone', 'Review Count', 'Average Rating',
                      'Review URL', 'Google Maps URL', 'Latitude', 'Longitude', 'Website',
                     'Opening Hours', 'Featured Image']]
df_surabaya
# Out:
#                         Name  \
# 0            Rabbani Laundry
# 1            ZAM ZAM Laundry
# 2               Twin laundry
# 3            EXPRESS Laundry
# 4           Laundry Asbar 22
# ..                       ...
# 290    Oxy Laundry Margorejo
# 291  @HOME Laundry Indonesia
# 292    Barokah Clean Laundry
# 293             Zuma Laundry
# 294           CICUCI Laundry
#
#                                            Fulladdress  \
# 0    Jl. Asem Raya No.5, Asem Rowo, Kec. Asem Rowo,...
# 1    Asemrowo IV No.16, Asem Rowo, Kec. Asem Rowo, ...
# 2    Jl. Asem Rowo Baru No.32, RT.001/RW.03, Asem R...
# 3    Jl. Asem Mulya V No.20, Asem Rowo, Kec. Asem R...
# 4    Jl. Asem Rowo Baru No.22, Asem Rowo, Kec. Asem...
# ..                                                 ...
# 290  Jl. Margorejo Indah No.28f, Margorejo, Kec. Wo...
# 291  No Jl. Siwalankerto Sel., Siwalankerto, Kec. W...
# 292  Jl. Wonocolo Pabrik Kulit No.89, Jemur Wonosar...
# ...

# %%
df_surabaya.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             295 non-null    object
#  1   Fulladdress      295 non-null    object
#  2   Categories       295 non-null    object
#  3   phone            281 non-null    object
#  4   Review Count     295 non-null    int64
#  5   Average Rating   295 non-null    float64
#  6   Review URL       285 non-null    object
#  7   Google Maps URL  295 non-null    object
#  8   Latitude         295 non-null    float64
#  9   Longitude        295 non-null    float64
#  10  Website          46 non-null     object
#  11  Opening Hours    286 non-null    object
#  12  Featured Image   293 non-null    object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 30.1+ KB

# %%
# Fill in the blanks with 'None' because the data in those columns might be needed
# so the blanks are replaced with 'None' to avoid missing values.

df_surabaya = df_surabaya.fillna('None')
df_surabaya
# Out:
#                         Name  \
# 0            Rabbani Laundry
# 1            ZAM ZAM Laundry
# 2               Twin laundry
# 3            EXPRESS Laundry
# 4           Laundry Asbar 22
# ..                       ...
# 290    Oxy Laundry Margorejo
# 291  @HOME Laundry Indonesia
# 292    Barokah Clean Laundry
# 293             Zuma Laundry
# 294           CICUCI Laundry
#
#                                            Fulladdress  \
# 0    Jl. Asem Raya No.5, Asem Rowo, Kec. Asem Rowo,...
# 1    Asemrowo IV No.16, Asem Rowo, Kec. Asem Rowo, ...
# 2    Jl. Asem Rowo Baru No.32, RT.001/RW.03, Asem R...
# 3    Jl. Asem Mulya V No.20, Asem Rowo, Kec. Asem R...
# 4    Jl. Asem Rowo Baru No.22, Asem Rowo, Kec. Asem...
# ..                                                 ...
# 290  Jl. Margorejo Indah No.28f, Margorejo, Kec. Wo...
# 291  No Jl. Siwalankerto Sel., Siwalankerto, Kec. W...
# 292  Jl. Wonocolo Pabrik Kulit No.89, Jemur Wonosar...
# ...

# %%
df_surabaya.isna().sum()
# Out:
# Name               0
# Fulladdress        0
# Categories         0
# phone              0
# Review Count       0
# Average Rating     0
# Review URL         0
# Google Maps URL    0
# Latitude           0
# Longitude          0
# Website            0
# Opening Hours      0
# Featured Image     0
# dtype: int64

# %%
jakarta = pd.read_csv("https://raw.githubusercontent.com/elsamaulida5/machine-learning/main/cleaned%20data/jakarta_cleaned.csv")
jakarta
# Out:
#                            Name  \
# 0                  Kota Laundry
# 1                   JNV Laundry
# 2                    Dt Laundry
# 3           Wish & Wash Laundry
# 4                    Laundry 26
# ..                          ...
# 389                   QLaundry
# 390              GO LAUNDRY JKT
# 391  Mama Laundry - Golf Island
# 392              Nailah Laundry
# 393                Laundry City
#
#                                            Fulladdress  \
# 0    Jl. Cempaka Putih Raya No.129b Lantai 2, RT.6/...
# 1    Jl. Rawasari Sel. No.8, RT.14/RW.2, Cemp. Puti...
# 2    Putih, Jl. Percetakan Negara No.D769 No.1, RT....
# 3    Jl. Cempaka Putih Tengah XVII No.31 1, RT.1/RW...
# 4    Jl. Cempaka Putih Raya No.120, RT.8/RW.3, Cemp...
# ..                                                 ...
# 389  Jl. Tanah Pasir No.39, RT.3/RW.7, RW07, Kec. P...
# 390  Jl. Klp. Muda IV No.H 22 10, RT.10/RW.7, Tugu ...
# 391  Kamal Muara, Jkt Utara, Daerah Khusus Ibukota ...
# ...

# %%
# Separates the two objects in the 'Phones' column
jakarta[['telephone','phone']] = jakarta['Phones'].str.split(', ', expand=True)
jakarta.drop(columns=['Phones'], inplace=True)

# %%
# Drop the telephone field
jakarta.drop(columns=['telephone'], inplace=True)
jakarta['phone']
# Out:
# 0      +62 855-5555-8888
# 1      +62 812-8000-4680
# 2      +62 812-8787-9428
# 3      +62 813-1155-8855
# 4      +62 877-9546-0166
#              ...
# 389    +62 878-7575-4959
# 390    +62 813-8030-7668
# 391    +62 821-2888-9893
# 392                  NaN
# 393    +62 812-8498-9029
# Name: phone, Length: 394, dtype: object

# %%
df_jakarta = jakarta[['Name', 'Fulladdress', 'Categories', 'phone', 'Review Count', 'Average Rating',
                      'Review URL', 'Google Maps URL', 'Latitude', 'Longitude', 'Website',
                     'Opening Hours', 'Featured Image']]
df_jakarta
# Out:
#                            Name  \
# 0                  Kota Laundry
# 1                   JNV Laundry
# 2                    Dt Laundry
# 3           Wish & Wash Laundry
# 4                    Laundry 26
# ..                          ...
# 389                   QLaundry
# 390              GO LAUNDRY JKT
# 391  Mama Laundry - Golf Island
# 392              Nailah Laundry
# 393                Laundry City
#
#                                            Fulladdress  \
# 0    Jl. Cempaka Putih Raya No.129b Lantai 2, RT.6/...
# 1    Jl. Rawasari Sel. No.8, RT.14/RW.2, Cemp. Puti...
# 2    Putih, Jl. Percetakan Negara No.D769 No.1, RT....
# 3    Jl. Cempaka Putih Tengah XVII No.31 1, RT.1/RW...
# 4    Jl. Cempaka Putih Raya No.120, RT.8/RW.3, Cemp...
# ..                                                 ...
# 389  Jl. Tanah Pasir No.39, RT.3/RW.7, RW07, Kec. P...
# 390  Jl. Klp. Muda IV No.H 22 10, RT.10/RW.7, Tugu ...
# 391  Kamal Muara, Jkt Utara, Daerah Khusus Ibukota ...
# ...

# %%
df_jakarta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 394 entries, 0 to 393
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             394 non-null    object
#  1   Fulladdress      393 non-null    object
#  2   Categories       394 non-null    object
#  3   phone            359 non-null    object
#  4   Review Count     387 non-null    float64
#  5   Average Rating   387 non-null    float64
#  6   Review URL       387 non-null    object
#  7   Google Maps URL  394 non-null    object
#  8   Latitude         394 non-null    float64
#  9   Longitude        394 non-null    float64
#  10  Website          141 non-null    object
#  11  Opening Hours    377 non-null    object
#  12  Featured Image   392 non-null    object
# dtypes: float64(4), object(9)
# memory usage: 40.1+ KB

# %%
rows_to_change = ['Review Count', 'Average Rating']
df_jakarta[rows_to_change] = df_jakarta[rows_to_change].fillna(value=0)
df_jakarta
# Out:
# <ipython-input-29-64700dccb603>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jakarta[rows_to_change] = df_jakarta[rows_to_change].fillna(value=0)
#                            Name  \
# 0                  Kota Laundry
# 1                   JNV Laundry
# 2                    Dt Laundry
# 3           Wish & Wash Laundry
# 4                    Laundry 26
# ..                          ...
# 389                   QLaundry
# 390              GO LAUNDRY JKT
# 391  Mama Laundry - Golf Island
# 392              Nailah Laundry
# 393                Laundry City
#
#                                            Fulladdress  \
# 0    Jl. Cempaka Putih Raya No.129b Lantai 2, RT.6/...
# 1    Jl. Rawasari Sel. No.8, RT.14/RW.2, Cemp. Puti...
# ...

# %%
df_jakarta['Review Count'] = df_jakarta['Review Count'].astype(int)
# Out:
# <ipython-input-30-e240b0558423>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jakarta['Review Count'] = df_jakarta['Review Count'].astype(int)

# %%
# Fill in the blanks with 'None' because the data in those columns might be needed
# so the blanks are replaced with 'None' to avoid missing values.

df_jakarta = df_jakarta.fillna('None')
df_jakarta.isna().sum()
# Out:
# Name               0
# Fulladdress        0
# Categories         0
# phone              0
# Review Count       0
# Average Rating     0
# Review URL         0
# Google Maps URL    0
# Latitude           0
# Longitude          0
# Website            0
# Opening Hours      0
# Featured Image     0
# dtype: int64

# %%
medan = pd.read_csv("https://raw.githubusercontent.com/elsamaulida5/machine-learning/main/cleaned%20data/Medan.csv")
medan
# Out:
#                                               Name  \
# 0                        G&G Medan Express Laundry
# 1                                   Fathia Laundry
# 2                              ocean fresh laundry
# 3                                  PRATAMA Laundry
# 4                                   Nayala Laundry
# ..                                             ...
# 162                                 Vanili Laundry
# 163               Laundry The Daily Wash dr.mansur
# 164                             Tetanggamu Laundry
# 165      Mutiara Laundry Express Powered By DEXTER
# 166  Srikandi Laundry (Laundry Antar Jemput Medan)
#
#                                            Fulladdress  \
# 0    Jl. Seksama No.93, Sitirejo III, Kec. Medan Am...
# 1    Jl. Garu II A, Harjosari I, Kec. Medan Amplas,...
# 2    A M P L A S, Medan Amplas, A M P L A S, Kec. M...
# 3    Jl. Panglima Denai No.104, A M P L A S, Kec. M...
# 4    GMGW+HPM, Jl. Swadaya, gg.pete, Kec. Medan Amp...
# ...

# %%
df_medan = medan[['Name', 'Fulladdress', 'Categories', 'phone', 'Review Count', 'Average Rating',
                      'Review URL', 'Google Maps URL', 'Latitude', 'Longitude', 'Website',
                     'Opening Hours', 'Featured Image']]
df_medan
# Out:
#                                               Name  \
# 0                        G&G Medan Express Laundry
# 1                                   Fathia Laundry
# 2                              ocean fresh laundry
# 3                                  PRATAMA Laundry
# 4                                   Nayala Laundry
# ..                                             ...
# 162                                 Vanili Laundry
# 163               Laundry The Daily Wash dr.mansur
# 164                             Tetanggamu Laundry
# 165      Mutiara Laundry Express Powered By DEXTER
# 166  Srikandi Laundry (Laundry Antar Jemput Medan)
#
#                                            Fulladdress  \
# 0    Jl. Seksama No.93, Sitirejo III, Kec. Medan Am...
# 1    Jl. Garu II A, Harjosari I, Kec. Medan Amplas,...
# 2    A M P L A S, Medan Amplas, A M P L A S, Kec. M...
# 3    Jl. Panglima Denai No.104, A M P L A S, Kec. M...
# 4    GMGW+HPM, Jl. Swadaya, gg.pete, Kec. Medan Amp...
# ...

# %%
df_medan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             167 non-null    object
#  1   Fulladdress      166 non-null    object
#  2   Categories       167 non-null    object
#  3   phone            128 non-null    object
#  4   Review Count     167 non-null    int64
#  5   Average Rating   167 non-null    float64
#  6   Review URL       163 non-null    object
#  7   Google Maps URL  167 non-null    object
#  8   Latitude         167 non-null    float64
#  9   Longitude        167 non-null    float64
#  10  Website          167 non-null    int64
#  11  Opening Hours    126 non-null    object
#  12  Featured Image   166 non-null    object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 17.1+ KB

# %%
# Fill in the blanks with 'None' because the data in those columns might be needed
# so the blanks are replaced with 'None' to avoid missing values.

df_medan = df_medan.fillna('None')
df_medan.isna().sum()
# Out:
# Name               0
# Fulladdress        0
# Categories         0
# phone              0
# Review Count       0
# Average Rating     0
# Review URL         0
# Google Maps URL    0
# Latitude           0
# Longitude          0
# Website            0
# Opening Hours      0
# Featured Image     0
# dtype: int64

# %%
# Menggabungkan semua data secara vertikal
df = pd.concat([df_bandung, df_semarang, df_jakarta, df_surabaya, df_medan], ignore_index=True)
df
# Out:
#                                                    Name  \
# 0     Laundryklin Sudirman ( Laundry Antar Jemput Ba...
# 1                                      The Laundry Room
# 2                        Nadhif Laundry ciroyom bandung
# 3                                 Laundry Club Rajawali
# 4                                  EZpress Home Laundry
# ...                                                 ...
# 1221                                     Vanili Laundry
# 1222                   Laundry The Daily Wash dr.mansur
# 1223                                 Tetanggamu Laundry
# 1224          Mutiara Laundry Express Powered By DEXTER
# 1225      Srikandi Laundry (Laundry Antar Jemput Medan)
#
#                                             Fulladdress  \
# 0     Jl. Jend. Sudirman No.486, Ciroyom, Kec. Andir...
# 1     Jl. Ciroyom No.95/77, Dungus Cariang, Kec. And...
# 2     Gg. Sastra No.272/78, Dungus Cariang, Kec. And...
# 3     Jl. Rajawali Barat No.25, Garuda, Kec. Andir, ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1226 entries, 0 to 1225
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             1226 non-null   object
#  1   Fulladdress      1226 non-null   object
#  2   Categories       1226 non-null   object
#  3   phone            1226 non-null   object
#  4   Review Count     1226 non-null   int64
#  5   Average Rating   1226 non-null   float64
#  6   Review URL       1226 non-null   object
#  7   Google Maps URL  1226 non-null   object
#  8   Latitude         1226 non-null   float64
#  9   Longitude        1226 non-null   float64
#  10  Website          1226 non-null   object
#  11  Opening Hours    1226 non-null   object
#  12  Featured Image   1226 non-null   object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 124.6+ KB

# %%
output_name = 'Data_Cleaned.csv'
df.to_csv(output_name, index=False)

print(f"Cleaned data save to '{output_name}'")
# Out:
# Cleaned data save to 'Data_Cleaned.csv'

# %%
df['Categories'].unique()
# Out:
# array(['Layanan Binatu', 'Binatu',
#        'Layanan Binatu, Pemasok peralatan binatu yang dioperasikan dengan koin, Pemasok ',
#        'Binatu Cucian Kering', 'Layanan Binatu, Binatu',
#        'Jasa Pembersihan',
#        'Layanan Binatu, Jasa Pembersih Karpet, Binatu Cucian Kering, Binatu, Jasa Semir ',
#        'Layanan Binatu, Binatu Cucian Kering, Binatu',
#        'Binatu, Binatu Cucian Kering, Layanan Binatu',
#        'Binatu, Layanan Binatu',
#        'Layanan Binatu, Binatu Cucian Kering, Jasa Semir Sepatu',
#        'Layanan Binatu, Binatu Cucian Kering',
#        'Layanan Binatu, Pemasok peralatan binatu yang dioperasikan dengan koin, Binatu, ',
#        'Binatu, Pemasok peralatan binatu yang dioperasikan dengan koin',
#        'Pemasok peralatan binatu yang dioperasikan dengan koin, Binatu',
#        'Pemasok peralatan binatu yang dioperasikan dengan koin, Layanan Binatu',
#        'Layanan Binatu, Pusat Bisnis, Jasa Pembersih Karpet, Pemasok peralatan binatu ya',
# ...

# %%
#Membuat list uniqe dari data categories
def remove_duplicates(categories):
    split_categories = categories.split(',')
    unique_categories = set(cat.strip() for cat in split_categories)
    return ', '.join(unique_categories)

df['Unique_Categories'] = df['Categories'].apply(remove_duplicates)

unique_categories_set = set()
df['Unique_Categories'].str.split(', ').apply(unique_categories_set.update)

unique_categories_list = list(unique_categories_set)
unique_categories_list
# Out:
# ['',
#  'Layanan Pembersih Kulit',
#  'Reparasi Mes',
#  'Jasa Semir Sepatu',
#  'Reparasi Mesin Cuci & Pengering',
#  'Kantor Perusahaan',
#  'Toko Parfum',
#  'Jasa Pembersihan',
#  'Toko Mesin Cuci & Pengering',
#  'Grosir bahan kimia',
#  'Toko',
#  'Toko Elektronik',
#  'Binatu Cucian Ke',
#  'Toko Pakaian',
#  'Binatu',
#  'Toko Perlengkapan Rumah',
#  'Pemasok peralatan b',
#  'Pusat Bisnis',
#  'Layanan Binatu',
#  'Tukang Bersih-Bersih',
#  'Jasa Cuci Jok Mobil',
#  'Pemasok peralatan binatu yang dioperasikan dengan koin',
#  'Pemasok peralatan binatu yang dioperasikan dengan ko',
#  'Perusahaan',
#  'Pemasok peralatan binatu ya',
#  'Jasa Pembersih Karpet',
#  'Service establishment',
#  'Binatu Cucian Kering',
#  'Toko Reparasi Sepatu',
#  'Jasa Semir',
#  'Layanan Kebersihan',
#  'Reparasi Koper',
#  'Pemasok',
#  'Penginapan']

# %%
# Membuat keywords
# Fungsi untuk menetapkan keywords
def assign_keywords(services):
    keywords = []
    if 'Binatu' in services:
        keywords.extend(['just wash', 'iron wash'])
    if 'Binatu Cucian Kering' in services:
        keywords.append('dry cleaning')
    if 'Layanan Binatu' in services:
        keywords.extend(['just wash', 'iron wash', 'dry cleaning'])
    if 'koin' in services.lower():
        keywords.append('self laundry')
    if 'karpet' in services.lower():
       keywords.append('carpet laundry')
    if 'sepatu' in services.lower():
       keywords.append('shoe laundry')
    if 'jok' in services.lower():
       keywords.append('car seat laundry')
    return ', '.join(set(keywords))  # Menggunakan set untuk menghindari duplikasi keyword

# Terapkan fungsi ke DataFrame
df['Layanan'] = df['Categories'].apply(assign_keywords)

df
# Out:
#                                                    Name  \
# 0     Laundryklin Sudirman ( Laundry Antar Jemput Ba...
# 1                                      The Laundry Room
# 2                        Nadhif Laundry ciroyom bandung
# 3                                 Laundry Club Rajawali
# 4                                  EZpress Home Laundry
# ...                                                 ...
# 1221                                     Vanili Laundry
# 1222                   Laundry The Daily Wash dr.mansur
# 1223                                 Tetanggamu Laundry
# 1224          Mutiara Laundry Express Powered By DEXTER
# 1225      Srikandi Laundry (Laundry Antar Jemput Medan)
#
#                                             Fulladdress  \
# 0     Jl. Jend. Sudirman No.486, Ciroyom, Kec. Andir...
# 1     Jl. Ciroyom No.95/77, Dungus Cariang, Kec. And...
# 2     Gg. Sastra No.272/78, Dungus Cariang, Kec. And...
# 3     Jl. Rajawali Barat No.25, Garuda, Kec. Andir, ...
# ...

# %%
# Menambahkan kolom ID Laundry ke kolom pertama
df.insert(0, 'ID Laundry', range(1, len(df) + 1))
df
# Out:
#       ID Laundry                                               Name  \
# 0              1  Laundryklin Sudirman ( Laundry Antar Jemput Ba...
# 1              2                                   The Laundry Room
# 2              3                     Nadhif Laundry ciroyom bandung
# 3              4                              Laundry Club Rajawali
# 4              5                               EZpress Home Laundry
# ...          ...                                                ...
# 1221        1222                                     Vanili Laundry
# 1222        1223                   Laundry The Daily Wash dr.mansur
# 1223        1224                                 Tetanggamu Laundry
# 1224        1225          Mutiara Laundry Express Powered By DEXTER
# 1225        1226      Srikandi Laundry (Laundry Antar Jemput Medan)
#
#                                             Fulladdress  \
# 0     Jl. Jend. Sudirman No.486, Ciroyom, Kec. Andir...
# ...

# %%
laundry = df.drop(columns=['Unique_Categories'])
laundry.to_csv('laundry.csv', index=False)
laundry.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1226 entries, 0 to 1225
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID Laundry       1226 non-null   int64
#  1   Name             1226 non-null   object
#  2   Fulladdress      1226 non-null   object
#  3   Categories       1226 non-null   object
#  4   phone            1226 non-null   object
#  5   Review Count     1226 non-null   int64
#  6   Average Rating   1226 non-null   float64
#  7   Review URL       1226 non-null   object
#  8   Google Maps URL  1226 non-null   object
#  9   Latitude         1226 non-null   float64
#  10  Longitude        1226 non-null   float64
#  11  Website          1226 non-null   object
#  12  Opening Hours    1226 non-null   object
#  13  Featured Image   1226 non-null   object
#  14  Layanan          1226 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 143.8+ KB

# %%
# Gabungkan deskripsi menjadi satu kolom
laundry['description'] = laundry['Fulladdress'] + ' ' + laundry['Categories'] + ' ' + laundry['Layanan']
laundry['description']
# Out:
# 0       Jl. Jend. Sudirman No.486, Ciroyom, Kec. Andir...
# 1       Jl. Ciroyom No.95/77, Dungus Cariang, Kec. And...
# 2       Gg. Sastra No.272/78, Dungus Cariang, Kec. And...
# 3       Jl. Rajawali Barat No.25, Garuda, Kec. Andir, ...
# 4       Jl. Durman No.4, Kb. Jeruk, Kec. Andir, Kota B...
#                               ...
# 1221    Jl. Vanili Raya No.99, Mangga, Kec. Medan Tunt...
# 1222    Jl. Dr. Mansyur No.27, Padang Bulan Selayang I...
# 1223    Jl. Prof. H. M. Yamin No.17b, Perintis, Kec. M...
# 1224    Jl. Arief Rahman Hakim No.136, RT.02, Ps. Mera...
# 1225    Jl. Sidorukun No.78b, Pulo Brayan Darat II, Ke...
# Name: description, Length: 1226, dtype: object

# %%
# Load pre-trained embedding model dari TensorFlow Hub
import tensorflow_hub as hub
embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# %%
# Buat embeddings untuk deskripsi laundry
descriptions = laundry['description'].tolist()
description_embeddings = embed(descriptions).numpy()

# %%
# Membuat label target
import numpy as np
target = np.random.randint(0, 2, len(descriptions))

# %% [markdown]
# # Membuat Model

# %% [markdown]
# ### Model Sistem Rekomendasi (Terdekat)

# %% [markdown]
# #### Model_Near (kNN)

# %%
import numpy as np
from sklearn.neighbors import NearestNeighbors
import pickle

def build_knn_model(laundry, n_neighbors=8):
    # Data tempat (koordinat)
    place_coords = laundry[['Latitude', 'Longitude']].values

    # Model k-NN
    knn = NearestNeighbors(n_neighbors=n_neighbors, metric='haversine')
    knn.fit(np.radians(place_coords))

    # Save the fitted kNN model and place coordinates
    with open('knn_model_Near.pkl', 'wb') as f:
        pickle.dump({'knn': knn, 'place_coords': place_coords}, f)

# %%
# Menjalankan Model_kNN_Near.pkl
import numpy as np
import pandas as pd
import pickle
import math

# Fungsi Haversine
def haversine(lon1, lat1, lon2, lat2):
    lon1, lat1, lon2, lat2 = map(math.radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = math.sin(dlat/2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon/2)**2
    c = 2 * math.asin(math.sqrt(a))
    r = 6371
    return c * r

def load_knn_model(model_file):
    with open(model_file, 'rb') as f:
        model_data = pickle.load(f)
    return model_data['knn'], model_data['place_coords']

def find_nearest_places(laundry, user_location, n_neighbors=8, model_file='knn_model_Near.pkl'):
    knn, place_coords = load_knn_model(model_file)

    # Jarak tempat terdekat dari pengguna
    distances, indices = knn.kneighbors([np.radians(user_location)])

    # Ambil data tempat terdekat dari DataFrame
    nearest_places = laundry.iloc[indices[0]].copy()

    # Hitung jarak untuk setiap tempat terdekat
    nearest_places['Distance'] = nearest_places.apply(
        lambda row: haversine(user_location[1], user_location[0], row['Longitude'], row['Latitude']), axis=1
    )

    # Hitung skor kecocokan
    nearest_places['Score'] = nearest_places['Average Rating'] / (nearest_places['Distance'] + 1)

    # Urutkan tempat terdekat berdasarkan skor kecocokan
    nearest_places_sorted = nearest_places.sort_values(by='Score', ascending=False)

    return nearest_places_sorted

def print_nearest_places(nearest_places, user_location):
    selected_columns = ['Name', 'Fulladdress', 'Categories', 'phone', 'Average Rating', 'Google Maps URL', 'Score']

    print("Tempat terdekat dengan skor kecocokan tertinggi:")
    for i in range(len(nearest_places)):
        selected_info = nearest_places.iloc[i]
        distance = haversine(user_location[1], user_location[0], selected_info['Longitude'], selected_info['Latitude'])
        print(f"Name: {selected_info['Name']}")
        print(f"Fulladdress: {selected_info['Fulladdress']}")
        print(f"Categories: {selected_info['Categories']}")
        print(f"Phone: {selected_info['phone']}")
        print(f"Average Rating: {selected_info['Average Rating']}")
        print(f"Google Maps URL: {selected_info['Google Maps URL']}")
        print(f"Website: {selected_info['Website']}")
        print(f"Distance: {distance:.2f} km")
        print(f"Score: {selected_info['Score']}")
        print()

# Contoh penggunaan fungsi
user_location = np.array([-7.316781, 112.761146])
nearest_places_sorted = find_nearest_places(laundry, user_location)
print_nearest_places(nearest_places_sorted, user_location)
# Out:
# Tempat terdekat dengan skor kecocokan tertinggi:
# Name: RA Laundry Metropolis
# Fulladdress: Apartemen Metropolis MS, Jl. Raya Tenggilis No.127, Jawa Timur 60292
# Categories: Layanan Binatu
# Phone: +62 813-5730-6710
# Average Rating: 5.0
# Google Maps URL: https://www.google.com/maps?cid=9396955328380271142
# Website: None
# Distance: 0.42 km
# Score: 3.5180497909350117
#
# Name: Fresh Laundry Tenggilis
# Fulladdress: Jl. Tenggilis Mulya No.124a, Tenggilis Mejoyo, Kec. Tenggilis Mejoyo, Surabaya,
# Categories: Layanan Binatu
# Phone: None
# Average Rating: 5.0
# Google Maps URL: https://www.google.com/maps?cid=16563556675789053527
# Website: None
# Distance: 0.53 km
# Score: 3.2769270415064193
#
# Name: ALAUNDRY
# Fulladdress: MQH5+Q63Tenggilis Mejoyo 101, Kec. Tenggilis Mejoyo, Surabaya, Jawa Timur 60292
# Categories: Binatu
# Phone: +62 812-1707-3047
# Average Rating: 5.0
# Google Maps URL: https://www.google.com/maps?cid=16985876686438263539
# Website: None
# Distance: 0.55 km
# ...

# %%
# Menjalankan Model_kNN_Near.pkl
import numpy as np
import pandas as pd
import pickle
import math

# Fungsi Haversine
def haversine(lon1, lat1, lon2, lat2):
    lon1, lat1, lon2, lat2 = map(math.radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = math.sin(dlat/2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon/2)**2
    c = 2 * math.asin(math.sqrt(a))
    r = 6371
    return c * r

def load_knn_model(model_file):
    with open(model_file, 'rb') as f:
        model_data = pickle.load(f)
    return model_data['knn'], model_data['place_coords']

def find_nearest_places(laundry, user_location, n_neighbors=8, model_file='knn_model_Near.pkl'):
    knn, place_coords = load_knn_model(model_file)

    # Jarak tempat terdekat dari pengguna
    distances, indices = knn.kneighbors([np.radians(user_location)])

    # Ambil data tempat terdekat dari DataFrame
    nearest_places = laundry.iloc[indices[0]].copy()

    # Hitung jarak untuk setiap tempat terdekat
    nearest_places['Distance'] = nearest_places.apply(
        lambda row: haversine(user_location[1], user_location[0], row['Longitude'], row['Latitude']), axis=1
    )

    # Hitung skor kecocokan
    nearest_places['Score'] = nearest_places['Average Rating'] / (nearest_places['Distance'] + 1)

    # Urutkan tempat terdekat berdasarkan skor kecocokan
    nearest_places_sorted = nearest_places.sort_values(by='Score', ascending=False)

    return nearest_places_sorted

def print_nearest_place_details(nearest_places_sorted, index):

    row = nearest_places_sorted.iloc[index]
    print(f"Nama Laundry: {row['Name']}")
    print(f"Alamat Lengkap: {row['Fulladdress']}")
    print(f"Telepon: {row['phone']}")
    print(f"Rating: {row['Average Rating']}")
    print(f"Prediksi Rating: {row['Predicted_Rating']:.2f}")
    print(f"Jarak: {row['Distance']:.2f} km")
    print(f"Google Maps URL: {row['Google Maps URL']}")
    print(f"Website: {row['Website']}")
    print(f"Jam Buka: {row['Opening Hours']}")
    print(f"Layanan: {row['Layanan']}")
    print("\n")


def display_laundry_names(nearest_places_sorted):
  # Menampilkan daftar nama tempat laundry
    print("Daftar Tempat Laundry Terdekat:")
    for index, row in nearest_places_sorted.iterrows():
        print(f"{index + 1}. {row['Name']}")
    print("Pilih nomor untuk melihat deskripsi lengkap.")

    return len(nearest_places_sorted)

# %%
# Contoh penggunaan fungsi
user_location = np.array([-7.316781, 112.761146])
nearest_places_sorted = find_nearest_places(laundry, user_location)
display_laundry_names(nearest_places_sorted)

# Meminta input dari pengguna
try:
    pilihan = int(input("Masukkan nomor pilihan Anda: ")) - 1
    if 0 <= pilihan < len(nearest_places_sorted):
        print_nearest_place_details(nearest_places_sorted, pilihan)
    else:
        print("Pilihan tidak valid.")
except ValueError:
    print("Masukkan nomor yang valid.")
# Out:
# Daftar Tempat Laundry Terdekat:
# 1027. RA Laundry Metropolis
# 1025. Fresh Laundry Tenggilis
# 1028. ALAUNDRY
# 1024. Laundry with Care
# 1026. Ryns Laundry
# 1023. Wanio Resik Laundry - Tenggilis Ubaya
# 1030. Ganesha Laundry
# 933. UNIVERSAL LAUNDRY SURABAYA
# Pilih nomor untuk melihat deskripsi lengkap.
# Masukkan nomor pilihan Anda: 8
# Nama Laundry: UNIVERSAL LAUNDRY SURABAYA
# Alamat Lengkap: Jl. Raya Kalirungkut No.15 A, Kali Rungkut, Kec. Rungkut, Surabaya, Jawa Timur 6
# Telepon: +62 838-5454-0288
# Rating: 4.8
# Prediksi Rating: 4.70
# Jarak: 0.96 km
# Google Maps URL: https://www.google.com/maps?cid=12734535034535625764
# Website: None
# Jam Buka: Sabtu: [08.00-00.00], Minggu: [08.00-00.00], Senin: [08.00-00.00], Selasa: [08.0
# Layanan: iron wash, dry cleaning, just wash

# %%
# Evaluasi Model_kNN_Near.pkl
import numpy as np
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from sklearn.model_selection import KFold
import math

# Fungsi Haversine
def haversine(lon1, lat1, lon2, lat2):
    lon1, lat1, lon2, lat2 = map(math.radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = math.sin(dlat/2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon/2)**2
    c = 2 * math.asin(math.sqrt(a))
    r = 6371
    return c * r

def mean_distance_knn(X, n_neighbors=5, cv=5):
    kf = KFold(n_splits=cv, shuffle=True, random_state=42)
    mean_distances = []

    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]

        # Model k-NN
        knn = NearestNeighbors(n_neighbors=n_neighbors, metric='haversine')
        knn.fit(X_train)

        # Evaluasi model dengan data pengujian
        total_distance = 0

        for test_point in X_test:
            distances, _ = knn.kneighbors([test_point])
            min_distance = distances[0][0] * 6371  # Konversi dari radian ke kilometer
            total_distance += min_distance

        average_distance = total_distance / len(X_test)
        mean_distances.append(average_distance)

    return mean_distances

# Data tempat (contoh)
X = np.radians(laundry[['Latitude', 'Longitude']].values)

# Hitung Mean Distance dengan Cross-Validation
mean_distances = mean_distance_knn(X, n_neighbors=8, cv=8)
print(f"Cross-Validation Scores (Mean Distance): {mean_distances}")
print(f"Mean Cross-Validation Score (Mean Distance): {np.mean(mean_distances):.2f} km")
# Out:
# Cross-Validation Scores (Mean Distance): [0.3909967918432785, 5.770966483878293, 0.4738884747192804, 0.4594168320629739, 0.46615243224986, 0.49007646417837053, 0.4881098088475335, 0.43274505075429714]
# Mean Cross-Validation Score (Mean Distance): 1.12 km

# %% [markdown]
# #### Model_Near (Tensorflow)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Concatenate, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from geopy.distance import geodesic

def prepare_data(laundry, user_location):
    # Menambahkan fitur jarak ke lokasi pengguna
    laundry['Distance'] = laundry.apply(lambda row: geodesic(user_location, (row['Latitude'], row['Longitude'])).km, axis=1)

    # Membuat fitur dan label dengan fitur jarak
    features = laundry[['Latitude', 'Longitude', 'Distance']]
    labels = laundry['Average Rating']

    # Split data menjadi train dan test
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

    # Normalisasi fitur
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    return X_train_scaled, X_test_scaled, y_train, y_test

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

def build_model():
    # Input layer
    latitude_input = Input(shape=(1,), name='latitude')
    longitude_input = Input(shape=(1,), name='longitude')
    distance_input = Input(shape=(1,), name='distance')

    # Dense layers
    concat = Concatenate()([latitude_input, longitude_input, distance_input])
    dense1 = Dense(1024, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(concat)
    dropout1 = Dropout(0.2)(dense1)
    dense2 = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(dropout1)
    dropout2 = Dropout(0.2)(dense2)
    dense3 = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(dropout2)
    dense4 = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(dense3)
    output = Dense(1)(dense4)

    # Model
    model = Model(inputs=[latitude_input, longitude_input, distance_input], outputs=output)
    model.compile(optimizer='adam', loss='mse')  # Use MSE as the loss function

    return model

def train_model(model, X_train_scaled, X_test_scaled, y_train, y_test):
    # Membuat dataset TensorFlow dengan dua input terpisah
    def split_lat_lon_distance(features, label):
        latitude = features[0]
        longitude = features[1]
        distance = features[2]
        return {'latitude': latitude, 'longitude': longitude, 'distance': distance}, label

    # Membuat dataset dengan map function untuk memisahkan latitude dan longitude
    train_dataset = tf.data.Dataset.from_tensor_slices((X_train_scaled, y_train.values))
    train_dataset = train_dataset.shuffle(buffer_size=len(X_train_scaled)).map(split_lat_lon_distance).batch(32)

    test_dataset = tf.data.Dataset.from_tensor_slices((X_test_scaled, y_test.values))
    test_dataset = test_dataset.map(split_lat_lon_distance).batch(32)

    # Early stopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Melatih model
    history = model.fit(train_dataset, epochs=200, validation_data=test_dataset, callbacks=[early_stopping])

    # Evaluasi model
    loss = model.evaluate(test_dataset)
    print("Test Loss:", loss)

    # Prediksi
    y_pred = model.predict(test_dataset).flatten()  # Pastikan bentuknya sesuai
    # Menghitung metrik tambahan
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    print("Mean Absolute Error:", mae)
    print("Mean Squared Error:", mse)

    return history

# %%
def save_model(model, filename):
    model.save(filename)

def main(laundry, user_location):
    X_train_scaled, X_test_scaled, y_train, y_test = prepare_data(laundry, user_location)
    model = build_model()
    history = train_model(model, X_train_scaled, X_test_scaled, y_train, y_test)
    save_model(model, "model_Near.h5")
    return model, history

model, history = main(laundry, user_location)
# Out:
# Epoch 1/200
# 31/31 [==============================] - 2s 22ms/step - loss: 14.6618 - val_loss: 7.8965
# Epoch 2/200
# 31/31 [==============================] - 1s 22ms/step - loss: 6.7205 - val_loss: 5.1631
# Epoch 3/200
# 31/31 [==============================] - 1s 24ms/step - loss: 4.5910 - val_loss: 3.5788
# Epoch 4/200
# 31/31 [==============================] - 1s 21ms/step - loss: 3.4882 - val_loss: 2.7315
# Epoch 5/200
# 31/31 [==============================] - 1s 17ms/step - loss: 2.8153 - val_loss: 2.1840
# Epoch 6/200
# 31/31 [==============================] - 0s 15ms/step - loss: 2.3667 - val_loss: 2.0935
# Epoch 7/200
# 31/31 [==============================] - 1s 17ms/step - loss: 2.0136 - val_loss: 1.5840
# Epoch 8/200
# 31/31 [==============================] - 1s 17ms/step - loss: 1.8213 - val_loss: 1.4249
# Epoch 9/200
# 31/31 [==============================] - 1s 17ms/step - loss: 1.5972 - val_loss: 1.2699
# Epoch 10/200
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import load_model
# Load the saved model
model = load_model('model_Near.h5')

# Plot training & validation loss values
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.show()

# %%
# Menjalankan Model_Near.h5
import numpy as np
import pandas as pd
import pickle
import math
from keras.models import load_model

# Fungsi Haversine
def haversine(lon1, lat1, lon2, lat2):
    lon1, lat1, lon2, lat2 = map(math.radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = math.sin(dlat/2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon/2)**2
    c = 2 * math.asin(math.sqrt(a))
    r = 6371
    return c * r

def find_nearest_places(laundry, user_location, model_path):
    model = load_model(model_path)

    # Menghitung jarak dari lokasi pengguna ke setiap tempat
    laundry['Distance'] = laundry.apply(lambda row: haversine(user_location[1], user_location[0], row['Longitude'], row['Latitude']), axis=1)

    # Menggunakan model untuk mendapatkan prediksi rating berdasarkan lokasi pengguna
    predicted_ratings = model.predict({
        'latitude': laundry['Latitude'].values,
        'longitude': laundry['Longitude'].values,
        'distance': laundry['Distance'].values
    })

    # Menambahkan prediksi rating ke dataframe
    laundry['Predicted_Rating'] = predicted_ratings

    # Menyusun tempat berdasarkan prediksi rating dan jarak
    recommended_places = laundry.sort_values(by=['Distance', 'Predicted_Rating'], ascending=[True, False])

    # Membatasi hasil menjadi 10 tempat terdekat
    top_10_places = recommended_places.head(10)

    return top_10_places

def print_nearest_places(nearest_places, user_location):
    selected_columns = ['Name', 'Fulladdress', 'Categories', 'phone', 'Average Rating', 'Predicted_Rating', 'Distance', 'Google Maps URL','Website', 'Opening Hours', 'Layanan']

    for index, row in top_10_places.iterrows():
      print(f"Nama Laundry: {row['Name']}")
      print(f"Alamat Lengkap: {row['Fulladdress']}")
      print(f"Telepon: {row['phone']}")
      print(f"Rating: {row['Average Rating']}")
      print(f"Prediksi Rating: {row['Predicted_Rating']:.2f}")
      print(f"Jarak: {row['Distance']:.2f} km")
      print(f"Google Maps URL: {row['Google Maps URL']}")
      print(f"Website: {row['Website']}")
      print(f"Jam Buka: {row['Opening Hours']}")
      print(f"Layanan: {row['Layanan']}")
      print("\n")

# Contoh penggunaan fungsi
user_location = np.array([-7.316781, 112.761146])
nearest_places_sorted = find_nearest_places(laundry, user_location, "model_Near.h5")
print_nearest_places(nearest_places_sorted, user_location)
# Out:
# 39/39 [==============================] - 0s 5ms/step
# Nama Laundry: RA Laundry Metropolis
# Alamat Lengkap: Apartemen Metropolis MS, Jl. Raya Tenggilis No.127, Jawa Timur 60292
# Telepon: +62 813-5730-6710
# Rating: 5.0
# Prediksi Rating: 4.69
# Jarak: 0.42 km
# Google Maps URL: https://www.google.com/maps?cid=9396955328380271142
# Website: None
# Jam Buka: Sabtu: [07.00-21.00], Minggu: [07.00-21.00], Senin: [07.00-21.00], Selasa: [07.0
# Layanan: iron wash, dry cleaning, just wash
#
#
# Nama Laundry: Ryns Laundry
# Alamat Lengkap: Jl. Raya Tenggilis No.132, Tenggilis Mejoyo, Kec. Tenggilis Mejoyo, Surabaya, Ja
# Telepon: +62 819-3931-9098
# Rating: 4.7
# Prediksi Rating: 4.69
# Jarak: 0.49 km
# Google Maps URL: https://www.google.com/maps?cid=2994783431368864314
# Website: https://rynslaundry.wixsite.com/website
# Jam Buka: Sabtu: [06.30-22.00], Minggu: [06.30-22.00], Senin: [06.30-22.00], Selasa: [06.3
# Layanan: iron wash, dry cleaning, just wash
#
#
# ...

# %%
# Menjalankan Model_Near.h5
import numpy as np
import pandas as pd
import pickle
import math
from keras.models import load_model

# Fungsi Haversine
def haversine(lon1, lat1, lon2, lat2):
    lon1, lat1, lon2, lat2 = map(math.radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = math.sin(dlat/2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon/2)**2
    c = 2 * math.asin(math.sqrt(a))
    r = 6371
    return c * r

def find_nearest_places(laundry, user_location, model_path):
    model = load_model(model_path)

    # Menghitung jarak dari lokasi pengguna ke setiap tempat
    laundry['Distance'] = laundry.apply(lambda row: haversine(user_location[1], user_location[0], row['Longitude'], row['Latitude']), axis=1)

    # Menggunakan model untuk mendapatkan prediksi rating berdasarkan lokasi pengguna
    predicted_ratings = model.predict({
        'latitude': laundry['Latitude'].values,
        'longitude': laundry['Longitude'].values,
        'distance': laundry['Distance'].values
    })

    # Menambahkan prediksi rating ke dataframe
    laundry['Predicted_Rating'] = predicted_ratings

    # Menyusun tempat berdasarkan prediksi rating dan jarak
    recommended_places = laundry.sort_values(by=['Distance', 'Predicted_Rating'], ascending=[True, False])

    # Membatasi hasil menjadi 10 tempat terdekat
    top_10_places = recommended_places.head(10)

    return top_10_places

def display_laundry_names(top_10_places):
    # Menampilkan daftar nama tempat laundry
    print("Daftar Tempat Laundry Terdekat:")
    for index, row in top_10_places.iterrows():
        print(f"{index + 1}. {row['Name']}")
    print("\nPilih nomor untuk melihat deskripsi lengkap.")

def display_laundry_description(top_10_places, index):
    selected_columns = ['Name', 'Fulladdress', 'Categories', 'phone', 'Average Rating', 'Predicted_Rating', 'Distance', 'Google Maps URL','Website', 'Opening Hours', 'Layanan']

    row = top_10_places.iloc[index]
    print(f"Nama Laundry: {row['Name']}")
    print(f"Alamat Lengkap: {row['Fulladdress']}")
    print(f"Telepon: {row['phone']}")
    print(f"Rating: {row['Average Rating']}")
    print(f"Prediksi Rating: {row['Predicted_Rating']:.2f}")
    print(f"Jarak: {row['Distance']:.2f} km")
    print(f"Google Maps URL: {row['Google Maps URL']}")
    print(f"Website: {row['Website']}")
    print(f"Jam Buka: {row['Opening Hours']}")
    print(f"Layanan: {row['Layanan']}")
    print("\n")

# %%
# Contoh penggunaan fungsi
user_location = np.array([-7.316781, 112.761146])
nearest_places_sorted = find_nearest_places(laundry, user_location, "model_Near.h5")
display_laundry_names(nearest_places_sorted)

# Input dari pengguna untuk melihat deskripsi lengkap
try:
    pilihan = int(input("Masukkan nomor pilihan Anda: ")) - 1
    if 0 <= pilihan < len(nearest_places_sorted):
        display_laundry_description(nearest_places_sorted, pilihan)
    else:
        print("Pilihan tidak valid.")
except ValueError:
    print("Masukkan nomor yang valid.")
# Out:
# 39/39 [==============================] - 0s 3ms/step
# Daftar Tempat Laundry Terdekat:
# 1027. RA Laundry Metropolis
# 1026. Ryns Laundry
# 1024. Laundry with Care
# 1025. Fresh Laundry Tenggilis
# 1028. ALAUNDRY
# 1023. Wanio Resik Laundry - Tenggilis Ubaya
# 1030. Ganesha Laundry
# 933. UNIVERSAL LAUNDRY SURABAYA
# 934. Deli Laundry Rungkut
# 1031. Mamboe Laundry
#
# Pilih nomor untuk melihat deskripsi lengkap.
# Masukkan nomor pilihan Anda: 2
# Nama Laundry: Ryns Laundry
# Alamat Lengkap: Jl. Raya Tenggilis No.132, Tenggilis Mejoyo, Kec. Tenggilis Mejoyo, Surabaya, Ja
# Telepon: +62 819-3931-9098
# Rating: 4.7
# Prediksi Rating: 4.69
# Jarak: 0.49 km
# Google Maps URL: https://www.google.com/maps?cid=2994783431368864314
# Website: https://rynslaundry.wixsite.com/website
# Jam Buka: Sabtu: [06.30-22.00], Minggu: [06.30-22.00], Senin: [06.30-22.00], Selasa: [06.3
# Layanan: iron wash, dry cleaning, just wash
