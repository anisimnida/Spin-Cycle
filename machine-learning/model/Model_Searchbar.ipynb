# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import joblib

# %%
data = pd.read_csv('https://raw.githubusercontent.com/elsamaulida5/machine-learning/main/cleaned%20data/laundry.csv')
data
# Out:
#       ID Laundry                                               Name  \
# 0              1  Laundryklin Sudirman ( Laundry Antar Jemput Ba...
# 1              2                                   The Laundry Room
# 2              3                     Nadhif Laundry ciroyom bandung
# 3              4                              Laundry Club Rajawali
# 4              5                               EZpress Home Laundry
# ...          ...                                                ...
# 1221        1222                                     Vanili Laundry
# 1222        1223                   Laundry The Daily Wash dr.mansur
# 1223        1224                                 Tetanggamu Laundry
# 1224        1225          Mutiara Laundry Express Powered By DEXTER
# 1225        1226      Srikandi Laundry (Laundry Antar Jemput Medan)
#
#                                             Fulladdress  \
# 0     Jl. Jend. Sudirman No.486, Ciroyom, Kec. Andir...
# 1     Jl. Ciroyom No.95/77, Dungus Cariang, Kec. And...
# 2     Gg. Sastra No.272/78, Dungus Cariang, Kec. And...
# 3     Jl. Rajawali Barat No.25, Garuda, Kec. Andir, ...
# 4     Jl. Durman No.4, Kb. Jeruk, Kec. Andir, Kota B...
# ...                                                 ...
# 1221  Jl. Vanili Raya No.99, Mangga, Kec. Medan Tunt...
# 1222  Jl. Dr. Mansyur No.27, Padang Bulan Selayang I...
# 1223  Jl. Prof. H. M. Yamin No.17b, Perintis, Kec. M...
# 1224  Jl. Arief Rahman Hakim No.136, RT.02, Ps. Mera...
# 1225  Jl. Sidorukun No.78b, Pulo Brayan Darat II, Ke...
#
#                         Categories               phone  Review Count  \
# 0                   Layanan Binatu   +62 851-7335-8871           151
# 1                   Layanan Binatu     +62 22 20562320             3
# 2                           Binatu      +62 22 6036296             6
# 3                   Layanan Binatu   +62 851-7324-7944            33
# 4                   Layanan Binatu   +62 823-2020-9878            50
# ...                            ...                 ...           ...
# 1221                Layanan Binatu                 NaN             1
# 1222                        Binatu                 NaN            16
# 1223  Binatu, Binatu Cucian Kering   +62 812-6511-5252            71
# 1224                        Binatu                 NaN             9
# 1225          Binatu Cucian Kering  +62 895-3445-94449            14
#
#       Average Rating                                         Review URL  \
# 0                4.8  https://search.google.com/local/reviews?placei...
# 1                5.0  https://search.google.com/local/reviews?placei...
# 2                4.7  https://search.google.com/local/reviews?placei...
# 3                4.9  https://search.google.com/local/reviews?placei...
# 4                4.2  https://search.google.com/local/reviews?placei...
# ...              ...                                                ...
# 1221             5.0  https://search.google.com/local/reviews?placei...
# 1222             4.3  https://search.google.com/local/reviews?placei...
# 1223             5.0  https://search.google.com/local/reviews?placei...
# 1224             4.6  https://search.google.com/local/reviews?placei...
# 1225             5.0  https://search.google.com/local/reviews?placei...
#
#                                         Google Maps URL  Latitude   Longitude  \
# 0     https://www.google.com/maps?cid=94604019837086... -6.918552  107.586449
# 1     https://www.google.com/maps?cid=11162829296077... -6.909928  107.580838
# 2     https://www.google.com/maps?cid=16206958779682... -6.915349  107.585807
# 3     https://www.google.com/maps?cid=10211050715543... -6.911077  107.570868
# 4     https://www.google.com/maps?cid=89067263696846... -6.919917  107.599841
# ...                                                 ...       ...         ...
# 1221  https://www.google.com/maps?cid=13474658465171...  3.508912   98.632010
# 1222  https://www.google.com/maps?cid=91915042862606...  3.567332   98.651193
# 1223  https://www.google.com/maps?cid=17346466435953...  3.594387   98.680243
# 1224  https://www.google.com/maps?cid=33600404797552...  3.571973   98.703399
# 1225  https://www.google.com/maps?cid=43760197014251...  3.625611   98.687028
#
#                                                 Website  \
# 0                                                   NaN
# 1     https://www.instagram.com/the.laundry.room.ban...
# 2                                                   NaN
# 3          https://bit.ly/customer_laundryclub_rajawali
# 4                                                   NaN
# ...                                                 ...
# 1221                                                  0
# 1222                                                  0
# 1223                                                  0
# 1224                                                  0
# 1225                                                  0
#
#                                           Opening Hours  \
# 0     Sabtu: [07.00-21.00], Minggu: [07.00-21.00], S...
# 1     Sabtu: [Buka 24 jam], Minggu: [Buka 24 jam], S...
# 2     Sabtu: [08.00-20.00], Minggu: [08.00-20.00], S...
# 3     Sabtu: [07.00-20.00], Minggu: [09.00-17.00], S...
# 4     Sabtu: [07.00-18.00], Minggu: [Tutup], Senin: ...
# ...                                                 ...
# 1221                                                NaN
# 1222                                                NaN
# 1223  Minggu: [08.30-19.00], Senin: [08.30-19.00], S...
# 1224  Minggu: [09.00-22.00], Senin: [09.00-22.00], S...
# 1225  Minggu: [08.00-21.00], Senin: [08.00-21.00], S...
#
#                                          Featured Image  \
# 0     https://lh5.googleusercontent.com/p/AF1QipMUOc...
# 1     https://lh5.googleusercontent.com/p/AF1QipOt-O...
# 2     https://lh5.googleusercontent.com/p/AF1QipPN10...
# 3     https://lh5.googleusercontent.com/p/AF1QipMERU...
# 4     https://lh5.googleusercontent.com/p/AF1QipOy4x...
# ...                                                 ...
# 1221  https://streetviewpixels-pa.googleapis.com/v1/...
# 1222  https://lh5.googleusercontent.com/p/AF1QipPZbY...
# 1223  https://lh5.googleusercontent.com/p/AF1QipN-8x...
# 1224  https://lh5.googleusercontent.com/p/AF1QipMi-K...
# 1225  https://lh5.googleusercontent.com/p/AF1QipM2uw...
#
#                                  Layanan
# 0     just wash, dry cleaning, iron wash
# 1     just wash, dry cleaning, iron wash
# 2                   just wash, iron wash
# 3     just wash, dry cleaning, iron wash
# 4     just wash, dry cleaning, iron wash
# ...                                  ...
# 1221  just wash, dry cleaning, iron wash
# 1222                just wash, iron wash
# 1223  just wash, dry cleaning, iron wash
# 1224                just wash, iron wash
# 1225  just wash, dry cleaning, iron wash
#
# [1226 rows x 15 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# Preprocessing teks (contoh sederhana: lowercase)
data['Name'] = data['Name'].str.lower()
data['Fulladdress'] = data['Fulladdress'].str.lower()
data['Categories'] = data['Categories'].str.lower()
data['Layanan'] = data['Layanan'].str.lower()

# %%
# Gabungkan kolom teks yang relevan untuk pencarian
data['Description'] = data['Name'] + ' ' + data['Fulladdress'] + ' ' + data['Categories'] + ' ' + data['Layanan']
data.isna().sum()
# Out:
# ID Laundry           0
# Name                 0
# Fulladdress          2
# Categories           0
# phone              131
# Review Count         0
# Average Rating       0
# Review URL          24
# Google Maps URL      0
# Latitude             0
# Longitude            0
# Website            760
# Opening Hours      102
# Featured Image       8
# Layanan              3
# Description          5
# dtype: int64

# %%
# Mengganti nilai np.nan dengan string kosong
data['Description'].fillna('', inplace=True)
data.isna().sum()
# Out:
# ID Laundry           0
# Name                 0
# Fulladdress          2
# Categories           0
# phone              131
# Review Count         0
# Average Rating       0
# Review URL          24
# Google Maps URL      0
# Latitude             0
# Longitude            0
# Website            760
# Opening Hours      102
# Featured Image       8
# Layanan              3
# Description          0
# dtype: int64

# %%
# Inisialisasi TF-IDF Vectorizer
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
# Fit dan transform deskripsi menjadi matriks TF-IDF
tfidf_matrix = tfidf_vectorizer.fit_transform(data['Description'])

# Simpan TF-IDF Vectorizer menggunakan joblib
joblib.dump(tfidf_vectorizer, 'tfidf_vectorizer.pkl')
# Out:
# ['tfidf_vectorizer.pkl']

# %%
# Fungsi pencarian berbasis teks
def cari_tempat_laundry(keyword, data, tfidf_matrix, tfidf_vectorizer):
    # Transform kata kunci menjadi vektor TF-IDF
    keyword_vec = tfidf_vectorizer.transform([keyword.lower()])

    # Hitung similaritas kosinus antara keyword_vec dan semua dokumen
    similarities = cosine_similarity(keyword_vec, tfidf_matrix).flatten()

    # Dapatkan indeks urutan similaritas tertinggi
    index_sorted = similarities.argsort()[::-1]

    # Ambil data tempat laundry yang paling relevan
    hasil_pencarian = data.iloc[index_sorted]
    hasil_pencarian = hasil_pencarian.head(30)

    return hasil_pencarian

# %%
# Contoh pencarian dengan keyword 'laundry harga terjangkau'
keyword = 'bandung'
hasil = cari_tempat_laundry(keyword, data, tfidf_matrix, tfidf_vectorizer)
print(hasil[['Name',	'Fulladdress',	'phone', 'Average Rating',	'Google Maps URL',	'Website',	'Opening Hours',	'Featured Image',	'Layanan']])
# Out:
#                                                   Name  \
# 243                             laundry kiloan bandung
# 240       amala express laundry bandung & wet cleaning
# 152  fruits digital laundry bandung (laundry gratis...
# 54                                     raundry laundry
# 212                            laundry express bandung
# 67                               gajah laundry bandung
# 77                                      bubble laundry
# 236                      superclean laundry bandung #1
# 208                                       rifa laundry
# 66                                       putri laundry
# 65                                       setya laundry
# 215                   laundry express bandung cabang 2
# 245                dr laundry balaikota - antar jemput
# 144                                    rairaka laundry
# 55                         fresh clean laundry bandung
# 34                       moza laundry & vacuum bandung
# 105                            heyklin laundry bandung
# 70                              speed laundry (cabang)
# 74                                       5asec bandung
# 27                               sachi laundry bandung
# 63                               fast to clean laundry
# 224  sorcha laundry cihampelas (laundry antar jempu...
# 58   sorcha laundry buah batu (laundry antar jemput...
# 32                             brother laundry bandung
# 229                          nusantara laundry bandung
# 244           laundry kiloan express - you can laundry
# 57   premium & hygienic laundry (p h laundry) l kot...
# 68   sorcha laundry gasibu (laundry antar jemput ba...
# 209  laundryklin margahayu (laundry antar jemput ba...
# 241                  made 2 clean laundromat siliwangi
#
#                                            Fulladdress               phone  \
# 243  jl. aceh no.22, babakan ciamis, kec. sumur ban...   +62 812-9072-4141
# 240  jl. merdeka no.25 - 27, babakan ciamis, kec. s...   +62 819-0819-6626
# 152  jl. cijambe no.32, pasir endah, kec. ujung ber...   +62 877-2873-3626
# 54   jl. sekelimus utara no.103, batununggal, kec. ...     +62 817-388-172
# 212  jl. pasundan no.58, balonggede, kec. regol, ko...   +62 851-7248-8338
# 67   jl. wayang no.8, malabar, kec. lengkong, kota ...   +62 822-2888-3434
# 77   jl. kebon bibit no.9, tamansari, kec. bandung ...   +62 821-2729-1776
# 236  jl. sukasari i no.11a, sekeloa, kecamatan cobl...                 NaN
# 208  jl. riung bandung raya no.5c, cipamokolan, kec...   +62 812-2085-0529
# 66   gg. manunggal iic no.58, cijerah, kec. bandung...      +62 22 6022052
# 65   jl. melong asih, cijerah, kec. bandung kulon, ...     +62 818-619-798
# 215  jl. pasundan no.21b, balonggede, kec. regol, k...   +62 851-8312-2135
# 245  babakan ciamis, kec. sumur bandung, kota bandu...                 NaN
# 144  jl bukit hegar, no. 20, ciumbuleuit, cidadap, ...      +62 22 2036336
# 55   jl. cijawura hilir no.14, cijaura, kec. buahba...   +62 896-5662-3999
# 34   jl. purbasari raya no.3, cisaranten kulon, kec...   +62 812-2411-1202
# 105  jl. cigadung raya timur, cigadung, kec. cibeun...                 NaN
# 70   gg. nangkasuni no.19, rt.04/rw.18, tamansari, ...   +62 822-1918-6400
# 74   jalan r.e. martadinata no.58 babakan ciamis, c...      +62 22 4238907
# 27   jl. cibatu raya no.42b, antapani tengah, kec. ...  +62 895-3445-02000
# 63   blok cibiuk no.166, cijerah, kec. bandung kulo...   +62 821-1821-6988
# 224  jl. boscha no.33, pasteur, kec. sukajadi, kota...   +62 851-7305-1808
# 58   jl. jati indah raya no.24, turangga, kec. leng...   +62 851-7317-4898
# 32   jl. cisaranten kulon no.32, cisaranten kulon, ...   +62 821-1654-0060
# 229  4h5p+3wq, jl. pdam, sukagalih, kec. sukajadi, ...   +62 812-2061-2340
# 244  jl. babakan ciamis no.34, babakan ciamis, kec....  +62 882-0001-98598
# 57   jl. rd rangga kencana no.5, mekarwangi, kec. b...   +62 878-1110-7999
# 68   jl. haur pancuh no.01 blok c, lebakgede, kecam...   +62 851-7305-1808
# 209  jl. jupiter tengah no.1a, sekejati, kec. buahb...   +62 812-2162-2021
# 241  3jq9+7jx, jl. belitung, merdeka, kec. sumur ba...    +62 811-2091-018
#
#      Average Rating                                    Google Maps URL  \
# 243             4.9  https://www.google.com/maps?cid=14656189232363...
# 240             4.8  https://www.google.com/maps?cid=97801477239436...
# 152             4.7  https://www.google.com/maps?cid=10899157800889...
# 54              4.7  https://www.google.com/maps?cid=19151422252136...
# 212             4.9  https://www.google.com/maps?cid=12487079774994...
# 67              4.8  https://www.google.com/maps?cid=73464865654521...
# 77              4.6  https://www.google.com/maps?cid=15834892417891...
# 236             5.0  https://www.google.com/maps?cid=18075758471045...
# 208             4.5  https://www.google.com/maps?cid=28576563805818...
# 66              5.0  https://www.google.com/maps?cid=77968832390455...
# 65              5.0  https://www.google.com/maps?cid=10347420049141...
# 215             5.0  https://www.google.com/maps?cid=88737767767691...
# 245             5.0  https://www.google.com/maps?cid=17489176869186...
# 144             5.0  https://www.google.com/maps?cid=57473269749259...
# 55              4.9  https://www.google.com/maps?cid=12648585617156...
# 34              4.1  https://www.google.com/maps?cid=10730810214745...
# 105             5.0  https://www.google.com/maps?cid=58168399165326...
# 70              4.9  https://www.google.com/maps?cid=18432974540496...
# 74              4.5  https://www.google.com/maps?cid=16950288675718...
# 27              5.0  https://www.google.com/maps?cid=13638352769791...
# 63              0.0  https://www.google.com/maps?cid=39954485300788...
# 224             5.0  https://www.google.com/maps?cid=18022121347460...
# 58              5.0  https://www.google.com/maps?cid=50792462198151...
# 32              5.0  https://www.google.com/maps?cid=38412912035714...
# 229             5.0  https://www.google.com/maps?cid=17508953595959...
# 244             4.8  https://www.google.com/maps?cid=10289519001392...
# 57              4.8  https://www.google.com/maps?cid=79845425351363...
# 68              4.9  https://www.google.com/maps?cid=74755072776068...
# 209             4.9  https://www.google.com/maps?cid=49092335079730...
# 241             4.9  https://www.google.com/maps?cid=63884191120235...
#
#                                                Website  \
# 243                                                NaN
# 240                                                NaN
# 152                                                NaN
# 54                                                 NaN
# 212                                                NaN
# 67           https://gajahlaundrybandung.blogspot.com/
# 77                                                 NaN
# 236                                                NaN
# 208                                                NaN
# 66                                                 NaN
# 65                                                 NaN
# 215                                                NaN
# 245                               http://drlaundry.id/
# 144                                                NaN
# 55       http://freshcleanlaundrybandung.blogspot.com/
# 34                                                 NaN
# 105                                                NaN
# 70                                                 NaN
# 74                      http://www.5asecindonesia.com/
# 27                                                 NaN
# 63                                                 NaN
# 224                      http://sorcha-cihampelas.com/
# 58   https://www.sorchalaundry.com/outlet-kami/sorc...
# 32                                                 NaN
# 229                                                NaN
# 244                        http://wa.me/62882000198598
# 57   https://premium-hygienic-laundry-p-h-laundry.b...
# 68                           http://sorchalaundry.com/
# 209  https://api.whatsapp.com/send?phone=6281221622...
# 241                                                NaN
#
#                                          Opening Hours  \
# 243  Sabtu: [07.00-17.30], Minggu: [Tutup], Senin: ...
# 240  Sabtu: [08.00-19.00], Minggu: [08.00-19.00], S...
# 152  Sabtu: [07.00-20.00], Minggu: [07.00-20.00], S...
# 54   Sabtu: [08.00-20.00], Minggu: [08.00-20.00], S...
# 212  Sabtu: [08.00-20.00], Minggu: [08.00-20.00], S...
# 67   Sabtu: [08.00-17.00], Minggu: [Tutup], Senin: ...
# 77   Sabtu: [07.00-21.00], Minggu: [07.00-21.00], S...
# 236  Sabtu: [08.00-21.00], Minggu: [08.00-21.00], S...
# 208  Sabtu: [07.00-20.00], Minggu: [07.00-20.00], S...
# 66   Sabtu: [07.30-20.00], Minggu: [07.30-20.00], S...
# 65   Sabtu: [07.00-21.00], Minggu: [07.00-21.00], S...
# 215  Sabtu: [08.00-20.00], Minggu: [08.00-20.00], S...
# 245  Sabtu: [07.00-20.00], Minggu: [07.00-20.00], S...
# 144                                                NaN
# 55   Sabtu: [07.00-19.00], Minggu: [07.00-19.00], S...
# 34   Sabtu: [07.00-21.00], Minggu: [07.00-21.00], S...
# 105                                                NaN
# 70   Sabtu: [08.00-17.00], Minggu: [08.00-17.00], S...
# 74   Sabtu: [08.00-19.00], Minggu: [Tutup], Senin: ...
# 27   Sabtu: [08.00-19.00], Minggu: [08.00-19.00], S...
# 63   Sabtu: [Buka 24 jam], Minggu: [Buka 24 jam], S...
# 224  Sabtu: [07.00-20.00], Minggu: [07.00-20.00], S...
# 58   Sabtu: [07.00-20.00], Minggu: [07.00-20.00], S...
# 32   Sabtu: [07.30-20.30], Minggu: [07.30-20.30], S...
# 229  Sabtu: [Buka 24 jam], Minggu: [Buka 24 jam], S...
# 244  Sabtu: [07.00-18.00], Minggu: [Tutup], Senin: ...
# 57   Sabtu: [08.00-18.00], Minggu: [Tutup], Senin: ...
# 68   Sabtu: [07.00-20.00], Minggu: [07.00-20.00], S...
# 209  Sabtu: [07.00-21.00], Minggu: [07.00-21.00], S...
# 241  Sabtu: [07.00-21.00], Minggu: [07.00-21.00], S...
#
#                                         Featured Image  \
# 243  https://lh5.googleusercontent.com/p/AF1QipMg0p...
# 240  https://lh5.googleusercontent.com/p/AF1QipPyhF...
# 152  https://lh5.googleusercontent.com/p/AF1QipMpzX...
# 54   https://lh5.googleusercontent.com/p/AF1QipPsdC...
# 212  https://lh5.googleusercontent.com/p/AF1QipMAW3...
# 67   https://lh5.googleusercontent.com/p/AF1QipM5I-...
# 77   https://streetviewpixels-pa.googleapis.com/v1/...
# 236  https://lh5.googleusercontent.com/p/AF1QipMBRF...
# 208  https://lh5.googleusercontent.com/p/AF1QipPF25...
# 66   https://lh5.googleusercontent.com/p/AF1QipNF94...
# 65   https://lh5.googleusercontent.com/p/AF1QipMX86...
# 215  https://lh5.googleusercontent.com/p/AF1QipM7Vf...
# 245  https://lh5.googleusercontent.com/p/AF1QipMrJg...
# 144  https://streetviewpixels-pa.googleapis.com/v1/...
# 55   https://lh5.googleusercontent.com/p/AF1QipNUIl...
# 34   https://lh5.googleusercontent.com/p/AF1QipPH_B...
# 105  https://lh5.googleusercontent.com/p/AF1QipMI_h...
# 70   https://lh5.googleusercontent.com/p/AF1QipMJ_w...
# 74   https://lh5.googleusercontent.com/p/AF1QipPo3m...
# 27   https://lh5.googleusercontent.com/p/AF1QipOd_M...
# 63   https://lh5.googleusercontent.com/p/AF1QipMLdb...
# 224  https://lh5.googleusercontent.com/p/AF1QipORX3...
# 58   https://lh5.googleusercontent.com/p/AF1QipPa3B...
# 32   https://lh5.googleusercontent.com/p/AF1QipPXJL...
# 229  https://lh5.googleusercontent.com/p/AF1QipO7Vq...
# 244  https://lh5.googleusercontent.com/p/AF1QipOx2C...
# 57   https://lh5.googleusercontent.com/p/AF1QipPHj-...
# 68   https://lh5.googleusercontent.com/p/AF1QipPBm6...
# 209  https://lh5.googleusercontent.com/p/AF1QipP6WH...
# 241  https://lh5.googleusercontent.com/p/AF1QipNtgn...
#
#                                 Layanan
# 243  just wash, dry cleaning, iron wash
# 240                just wash, iron wash
# 152                just wash, iron wash
# 54   just wash, dry cleaning, iron wash
# 212  just wash, dry cleaning, iron wash
# 67                 just wash, iron wash
# 77   just wash, dry cleaning, iron wash
# 236                just wash, iron wash
# 208                just wash, iron wash
# 66   just wash, dry cleaning, iron wash
# 65   just wash, dry cleaning, iron wash
# 215  just wash, dry cleaning, iron wash
# 245  just wash, dry cleaning, iron wash
# 144  just wash, dry cleaning, iron wash
# 55                 just wash, iron wash
# 34                 just wash, iron wash
# 105  just wash, dry cleaning, iron wash
# 70                 just wash, iron wash
# 74   just wash, dry cleaning, iron wash
# 27                 just wash, iron wash
# 63   just wash, dry cleaning, iron wash
# 224  just wash, dry cleaning, iron wash
# 58                 just wash, iron wash
# 32   just wash, dry cleaning, iron wash
# 229  just wash, dry cleaning, iron wash
# 244                just wash, iron wash
# 57   just wash, dry cleaning, iron wash
# 68                 just wash, iron wash
# 209  just wash, dry cleaning, iron wash
# 241                just wash, iron wash
